# %% [markdown]
# Importing pandas

# %%
import pandas as pd

# %% [markdown]
# Uploading the dataset, df

# %%
df = pd.read_csv('Advanced_pandas_sales_dataset.csv')
df.head()
# Out:
#    Order_ID  Order_Date Customer       City Region   Product     Category  \
# 0      1001  2024-10-01    Priya  Hyderabad   East     Mouse  Accessories
# 1      1002  2024-05-03    Sneha    Kolkata   East   Monitor  Electronics
# 2      1003  2024-01-26    Anita     Mumbai   West     Phone  Electronics
# 3      1004  2024-06-06     Sara       Pune   East  Keyboard  Accessories
# 4      1005  2024-10-15    Rahul  Bangalore  South   Monitor  Electronics
#
#    Sales  Quantity  Discount  Profit
# 0   1735         7      0.00  307.52
# 1    807         2      0.15   49.89
# 2   2328         1      0.20   66.47
# 3   3933         3      0.20  -71.66
# 4   3550         2      0.20  146.30

# %% [markdown]
# Question 1:  Dataset Exploration
#
#           Perform the following exploratory steps:
#                Display the first 10 rows
#                Display the dataset structure using info()
#                Find the number of rows and columns
#                Identify the data types of each column

# %%
# Displaying the first 10 rows of the dataset 
df.head(10)
# Out:
#    Order_ID  Order_Date Customer       City Region   Product     Category  \
# 0      1001  2024-10-01    Priya  Hyderabad   East     Mouse  Accessories
# 1      1002  2024-05-03    Sneha    Kolkata   East   Monitor  Electronics
# 2      1003  2024-01-26    Anita     Mumbai   West     Phone  Electronics
# 3      1004  2024-06-06     Sara       Pune   East  Keyboard  Accessories
# 4      1005  2024-10-15    Rahul  Bangalore  South   Monitor  Electronics
# 5      1006  2024-07-04    Pooja  Bangalore   West   Printer       Office
# 6      1007  2024-06-24      Dev    Chennai   East   Monitor  Electronics
# 7      1008  2024-03-18    Kavya    Kolkata   East     Phone  Electronics
# 8      1009  2024-10-31    Kavya  Ahmedabad   East     Phone  Electronics
# 9      1010  2024-12-25    Pooja  Ahmedabad  North     Phone  Electronics
#
#    Sales  Quantity  Discount  Profit
# 0   1735         7      0.00  307.52
# 1    807         2      0.15   49.89
# 2   2328         1      0.20   66.47
# ...

# %%
# alternatively 
df.iloc[:10]
# Out:
#    Order_ID  Order_Date Customer       City Region   Product     Category  \
# 0      1001  2024-10-01    Priya  Hyderabad   East     Mouse  Accessories
# 1      1002  2024-05-03    Sneha    Kolkata   East   Monitor  Electronics
# 2      1003  2024-01-26    Anita     Mumbai   West     Phone  Electronics
# 3      1004  2024-06-06     Sara       Pune   East  Keyboard  Accessories
# 4      1005  2024-10-15    Rahul  Bangalore  South   Monitor  Electronics
# 5      1006  2024-07-04    Pooja  Bangalore   West   Printer       Office
# 6      1007  2024-06-24      Dev    Chennai   East   Monitor  Electronics
# 7      1008  2024-03-18    Kavya    Kolkata   East     Phone  Electronics
# 8      1009  2024-10-31    Kavya  Ahmedabad   East     Phone  Electronics
# 9      1010  2024-12-25    Pooja  Ahmedabad  North     Phone  Electronics
#
#    Sales  Quantity  Discount  Profit
# 0   1735         7      0.00  307.52
# 1    807         2      0.15   49.89
# 2   2328         1      0.20   66.47
# ...

# %%
#  Displaying the dataset structure using info() 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230 entries, 0 to 229
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    230 non-null    int64
#  1   Order_Date  230 non-null    object
#  2   Customer    230 non-null    object
#  3   City        230 non-null    object
#  4   Region      230 non-null    object
#  5   Product     230 non-null    object
#  6   Category    230 non-null    object
#  7   Sales       230 non-null    int64
#  8   Quantity    230 non-null    int64
#  9   Discount    230 non-null    float64
#  10  Profit      230 non-null    float64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 19.9+ KB

# %%
# Finding the number of rows and columns   
df.shape
# Out:
# (230, 11)

# %%
# Identify the data types of each column 
df.dtypes
# Out:
# Order_ID        int64
# Order_Date     object
# Customer       object
# City           object
# Region         object
# Product        object
# Category       object
# Sales           int64
# Quantity        int64
# Discount      float64
# Profit        float64
# dtype: object

# %% [markdown]
# Question 2: Sales Filtering Analysis
#
#           Filter the dataset to display:
#
#              Orders where Sales > 3500
#              Orders where Region = "East" and Sales > 2500
#              Explain what insights you observe.

# %%
#  Orders where Sales > 3500 
df[df['Sales'] > 3500]
# Out:
#      Order_ID  Order_Date Customer       City Region   Product     Category  \
# 3        1004  2024-06-06     Sara       Pune   East  Keyboard  Accessories
# 4        1005  2024-10-15    Rahul  Bangalore  South   Monitor  Electronics
# 7        1008  2024-03-18    Kavya    Kolkata   East     Phone  Electronics
# 8        1009  2024-10-31    Kavya  Ahmedabad   East     Phone  Electronics
# 10       1011  2024-06-30     Neha      Delhi  South   Printer       Office
# ..        ...         ...      ...        ...    ...       ...          ...
# 219      1220  2024-03-22    Meera  Bangalore   West     Phone  Electronics
# 222      1223  2024-03-04    Meera  Ahmedabad  South     Phone  Electronics
# 223      1224  2024-01-07      Dev  Bangalore   East    Tablet  Electronics
# 225      1226  2024-06-14    Anita  Ahmedabad   East    Laptop  Electronics
# 229      1230  2024-04-13    Meera    Kolkata  North   Monitor  Electronics
#
#      Sales  Quantity  Discount   Profit
# ...

# %%
#  Orders where Region = "East" and Sales > 2500

df[(df['Region']=='East')  & (df['Sales']> 2500)]
# Out:
#      Order_ID  Order_Date Customer       City Region     Product     Category  \
# 3        1004  2024-06-06     Sara       Pune   East    Keyboard  Accessories
# 7        1008  2024-03-18    Kavya    Kolkata   East       Phone  Electronics
# 8        1009  2024-10-31    Kavya  Ahmedabad   East       Phone  Electronics
# 13       1014  2024-03-18    Anita  Bangalore   East       Mouse  Accessories
# 21       1022  2024-01-14    Nitin    Chennai   East     Monitor  Electronics
# 27       1028  2024-07-21      Dev    Kolkata   East      Tablet  Electronics
# 33       1034  2024-12-15    Nitin  Ahmedabad   East      Tablet  Electronics
# 34       1035  2024-02-20    Nitin  Ahmedabad   East      Laptop  Electronics
# 41       1042  2024-07-15    Rohan    Chennai   East      Laptop  Electronics
# 43       1044  2024-09-20    Kavya  Hyderabad   East     Printer       Office
# 52       1053  2024-05-24    Anita    Chennai   East       Phone  Electronics
# ...

# %% [markdown]
#  Explain what insights you observe.
#
#    Explanation:
#
#    Some orders for example Order ID 1004 compared to other orders, has higher sales of 3933 but it is in negative profits. The same also                  applied to order 1034 which also has negative profits.
#    This is most probably arising from products being purchased expensively by the business and then sold out to the customers at a loss.
#    There is need to outsource for products from suppliers who offer them at good rates to avoid having to sell items at a loss.

# %% [markdown]
# Question 3: Customer Purchase Analysis
#
#           Identify the top 5 customers based on total sales.
#           Hint: Use GroupBy with aggregation.

# %%
Top_5_customers = df.groupby('Customer')['Sales'].sum().nlargest(5)

# %%
print(Top_5_customers)
# Out:
# Customer
# Nitin    59820
# Raj      58416
# Rahul    52291
# Dev      48500
# Isha     46818
# Name: Sales, dtype: int64

# %% [markdown]
# Question 4: Regional Sales Performance
#
#           Calculate the total sales generated by each region.
#           Then identify:
#              Which region generated the highest revenue?

# %%
# total sales generated by each region 
total_sales_by_region = df.groupby('Region')['Sales'].sum() 
print(total_sales_by_region)
# Out:
# Region
# East     232675
# North    158210
# South    183108
# West     170227
# Name: Sales, dtype: int64

# %%
# region with the highest revenue 
highest_revenue_by_region = df.groupby('Region')['Sales'].sum().nlargest(1) 
print(highest_revenue_by_region)
# Out:
# Region
# East    232675
# Name: Sales, dtype: int64

# %% [markdown]
# Question 5: Product Performance Analysis
#
#           Calculate the total quantity sold for each product.
#           Which product appears to be the most popular?

# %% [markdown]
# # total quantity sold per product
#
# total_qty_per_product = df.groupby('Product')['Quantity'].sum()
# print(total_qty_per_product)

# %%
# product that appears to be the most popular 

most_popular_product = df.groupby('Product')['Quantity'].sum().nlargest(1) 
print(most_popular_product)
# Out:
# Product
# Monitor    156
# Name: Quantity, dtype: int64

# %% [markdown]
# Question 6: Multi-Level Grouping
#
#            Group the dataset by: Region and Category
#            Calculate the total sales for each combination.
#            What insights can you derive from this analysis?

# %%
# grouping the dataset by region and category 
df.groupby(['Region','Category']).head()
# Out:
#      Order_ID  Order_Date Customer       City Region     Product     Category  \
# 0        1001  2024-10-01    Priya  Hyderabad   East       Mouse  Accessories
# 1        1002  2024-05-03    Sneha    Kolkata   East     Monitor  Electronics
# 2        1003  2024-01-26    Anita     Mumbai   West       Phone  Electronics
# 3        1004  2024-06-06     Sara       Pune   East    Keyboard  Accessories
# 4        1005  2024-10-15    Rahul  Bangalore  South     Monitor  Electronics
# 5        1006  2024-07-04    Pooja  Bangalore   West     Printer       Office
# 6        1007  2024-06-24      Dev    Chennai   East     Monitor  Electronics
# 7        1008  2024-03-18    Kavya    Kolkata   East       Phone  Electronics
# 8        1009  2024-10-31    Kavya  Ahmedabad   East       Phone  Electronics
# 9        1010  2024-12-25    Pooja  Ahmedabad  North       Phone  Electronics
# 10       1011  2024-06-30     Neha      Delhi  South     Printer       Office
# ...

# %%
#  total sales for each combination 
df.groupby(['Region','Category'])['Sales'].sum()
# Out:
# Region  Category
# East    Accessories     57646
#         Electronics    160907
#         Office          14122
# North   Accessories     62052
#         Electronics     70023
#         Office          26135
# South   Accessories     80914
#         Electronics     86690
#         Office          15504
# West    Accessories     64811
#         Electronics     84128
#         Office          21288
# Name: Sales, dtype: int64

# %% [markdown]
# Insights derived from this analysis:
#
#     The most sales come from the East Region.
#
#     The sale of electronics generate the most sales
#
#     The sale of office stuff generates least sales

# %% [markdown]
# Question 7: Pivot Table Creation
#
#          Create a pivot table showing:
#             Rows → Region
#             Columns → Product
#             Values → Total Sales
#          Which region sells the most laptops?

# %%
# pivot table 
df.pivot_table(values='Sales',columns='Product',index='Region',aggfunc='sum')
# Out:
# Product  Headphones  Keyboard  Laptop  Monitor  Mouse  Phone  Printer  Tablet
# Region
# East          23899     10845   55568    31299  22902  39667    14122   34373
# North         15450     20538    4540    14922  26064  30535    26135   20026
# South         24111     23480   23029    19167  33323  18218    15504   26276
# West          17159     38499   10826    18178   9153  27850    21288   27274

# %%
# region that sells the most laptops 
df.pivot_table(values='Sales',columns='Product',index='Region',aggfunc='sum')['Laptop'].idxmax()
# Out:
# 'East'

# %% [markdown]
# Question 8: Profitability Analysis
#
#           Calculate the average profit for each product category.
#           Which category is most profitable?

# %%
# Average profit per product category 
df.groupby('Category')['Profit'].mean()
# Out:
# Category
# Accessories    410.603086
# Electronics    396.462114
# Office         471.938462
# Name: Profit, dtype: float64

# %%
# Most profitable category 
df.groupby('Category')['Profit'].mean().idxmax()
# Out:
# 'Office'

# %% [markdown]
# Question 9 :Discount Impact Study
#
#           Analyze the relationship between discount and profit.
#
#           Tasks:
#             Calculate the average profit for each discount level
#             Identify whether higher discounts lead to lower profit

# %%
# average profit for each discount level 
df.groupby('Discount')['Profit'].mean()
# Out:
# Discount
# 0.00    751.210588
# 0.05    531.368039
# 0.10    346.460513
# 0.15    237.191400
# 0.20     90.026923
# Name: Profit, dtype: float64

# %%
# finding out whether higher discounts lead to lower profit
pd.crosstab(df['Discount'],df['Profit'])
# Out:
# Profit    -104.30   -77.55    -71.66    -67.01    -58.60    -49.47    \
# Discount
# 0.00             0         0         0         0         0         0
# 0.05             0         0         0         0         0         0
# 0.10             0         0         0         0         0         0
# 0.15             0         0         0         0         0         0
# 0.20             1         1         1         1         1         1
#
# Profit    -39.13    -36.79    -26.75    -25.47    ...   1171.08   1245.37  \
# Discount                                          ...
# 0.00             0         0         0         0  ...         1         1
# 0.05             0         0         0         0  ...         0         0
# 0.10             0         0         0         0  ...         0         0
# 0.15             0         0         0         0  ...         0         0
# 0.20             1         1         1         1  ...         0         0
#
# ...

# %% [markdown]
# Profits are higher when discounts are lower.
# Therefore, the business has to minimize on discounts to elevate profits the more.

# %% [markdown]
# Question 10: End-to-End Data Wrangling Task
#
#            Perform the following workflow:
#             Filter the dataset where Sales > 3000
#             Group data by Region and Product
#             Calculate total sales
#             Reshape the result into a pivot table
#            Explain the business insights obtained from this analysis.

# %%
# dataset where Sales > 3000 
df[df['Sales'] > 3000]
# Out:
#      Order_ID  Order_Date Customer       City Region   Product     Category  \
# 3        1004  2024-06-06     Sara       Pune   East  Keyboard  Accessories
# 4        1005  2024-10-15    Rahul  Bangalore  South   Monitor  Electronics
# 5        1006  2024-07-04    Pooja  Bangalore   West   Printer       Office
# 7        1008  2024-03-18    Kavya    Kolkata   East     Phone  Electronics
# 8        1009  2024-10-31    Kavya  Ahmedabad   East     Phone  Electronics
# ..        ...         ...      ...        ...    ...       ...          ...
# 219      1220  2024-03-22    Meera  Bangalore   West     Phone  Electronics
# 222      1223  2024-03-04    Meera  Ahmedabad  South     Phone  Electronics
# 223      1224  2024-01-07      Dev  Bangalore   East    Tablet  Electronics
# 225      1226  2024-06-14    Anita  Ahmedabad   East    Laptop  Electronics
# 229      1230  2024-04-13    Meera    Kolkata  North   Monitor  Electronics
#
#      Sales  Quantity  Discount  Profit
# ...

# %%
# Grouping data by Region and Product 
df.groupby(['Region','Product']).head()
# Out:
#      Order_ID  Order_Date Customer       City Region     Product     Category  \
# 0        1001  2024-10-01    Priya  Hyderabad   East       Mouse  Accessories
# 1        1002  2024-05-03    Sneha    Kolkata   East     Monitor  Electronics
# 2        1003  2024-01-26    Anita     Mumbai   West       Phone  Electronics
# 3        1004  2024-06-06     Sara       Pune   East    Keyboard  Accessories
# 4        1005  2024-10-15    Rahul  Bangalore  South     Monitor  Electronics
# ..        ...         ...      ...        ...    ...         ...          ...
# 210      1211  2024-07-21      Dev  Bangalore  North     Monitor  Electronics
# 214      1215  2024-08-25    Sneha       Pune  North      Laptop  Electronics
# 218      1219  2024-02-16    Vikas  Hyderabad   West  Headphones  Accessories
# 222      1223  2024-03-04    Meera  Ahmedabad  South       Phone  Electronics
# 229      1230  2024-04-13    Meera    Kolkata  North     Monitor  Electronics
#
# ...

# %%
# total sales 
df['Sales'].sum()
# Out:
# np.int64(744220)

# %%
 #Reshaping the result into a pivot table 

# filtering Sales > 3000 
df_filtered = df[df['Sales']> 3000]

df_filtered.pivot_table(values='Sales',columns='Product',index='Region',aggfunc='sum')
# Out:
# Product  Headphones  Keyboard  Laptop  Monitor  Mouse  Phone  Printer  Tablet
# Region
# East          14469      9642   44096    16420  19000  29500     3696   29229
# North          5326     15653    4540     5087  22209  24670    17185    3392
# South         10026     19249   17950    14921  26928  18218    14143   19613
# West          13898     33380    5922    14354   3511  15653    12648   17185

# %% [markdown]
# Business insight derived from this analysis:
#
# The sale of phone generates the most sales
# The sale of tablet generates the least sales
# The East Region has the best sales
